# %% [markdown]
# <a href="https://colab.research.google.com/github/santoshdhalwalkar/DataAcq_wrangling/blob/main/dataAcq_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
import warnings
import datetime
warnings.filterwarnings("ignore")

# %%
data1=pd.read_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/dataset_1.xlsx")

# %%
data1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
data1.shape
# Out:
# (610, 10)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %% [markdown]
# ### In below code convert dteday dtype datetime to int format before column show date in this format 2011-01-01 after convtering to int it shows like this 20110101

# %%
data1['dteday'] = pd.to_datetime(data1['dteday']).dt.strftime('%Y%m%d').astype(int)

# %%
data1.info()
data1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    int64
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(8)
# memory usage: 43.6 KB
#      instant    dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  20110101       1   0     1   0    False        6           1
# 1          2  20110101       1   0     1   1    False        6           1
# 2          3  20110101       1   0     1   2    False        6           1
# ...

# %%
data1['weathersit'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
data1['weathersit'].value_counts()
# Out:
# weathersit
# 1    368
# 2    194
# 3     47
# 4      1
# Name: count, dtype: int64

# %%
data1['season'].unique()
# Out:
# array([1])

# %%
data1['season'].value_counts()
# Out:
# season
# 1    610
# Name: count, dtype: int64

# %%
data1['temp'].unique()
# Out:
# array([0.24, 0.22, 0.2 , 0.32, 0.38, 0.36, 0.42, 0.46, 0.44, 0.4 , 0.34,
#        0.3 , 0.26, 0.16, 0.14, 0.18, 0.12, 0.28, 0.1 , 0.08, 0.06, 0.04,
#        0.02])

# %%
data1.isnull()
# Out:
#      instant  dteday  season     yr   mnth     hr  holiday  weekday  \
# 0      False   False   False  False  False  False    False    False
# 1      False   False   False  False  False  False    False    False
# 2      False   False   False  False  False  False    False    False
# 3      False   False   False  False  False  False    False    False
# 4      False   False   False  False  False  False    False    False
# ..       ...     ...     ...    ...    ...    ...      ...      ...
# 605    False   False   False  False  False  False    False    False
# 606    False   False   False  False  False  False    False    False
# 607    False   False   False  False  False  False    False    False
# 608    False   False   False  False  False  False    False    False
# 609    False   False   False  False  False  False    False    False
#
#      weathersit   temp
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ...

# %%
data1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
data1
# Out:
#      instant    dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  20110101       1   0     1   0    False        6           1
# 1          2  20110101       1   0     1   1    False        6           1
# 2          3  20110101       1   0     1   2    False        6           1
# 3          4  20110101       1   0     1   3    False        6           1
# 4          5  20110101       1   0     1   4    False        6           1
# ..       ...       ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  20110128       1   0     1  11    False        5           3
# 606      607  20110128       1   0     1  12    False        5           3
# 607      608  20110128       1   0     1  13    False        5           3
# 608      609  20110128       1   0     1  14    False        5           3
# 609      610  20110128       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# ...

# %%
data1['yr'].unique()
# Out:
# array([0])

# %% [markdown]
# ### '**yr**' column have array value 0 only. I think yr column is not important so I think I can drop this column

# %%
data1.drop(['yr'], axis=1, inplace=True)
data1
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp
# 0          1  20110101       1     1   0    False        6           1  0.24
# 1          2  20110101       1     1   1    False        6           1  0.22
# 2          3  20110101       1     1   2    False        6           1  0.22
# 3          4  20110101       1     1   3    False        6           1  0.24
# 4          5  20110101       1     1   4    False        6           1  0.24
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 605      606  20110128       1     1  11    False        5           3  0.18
# 606      607  20110128       1     1  12    False        5           3  0.18
# 607      608  20110128       1     1  13    False        5           3  0.18
# 608      609  20110128       1     1  14    False        5           3  0.22
# 609      610  20110128       1     1  15    False        5           2  0.20
#
# [610 rows x 9 columns]

# %% [markdown]
# data1.to_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/dataset_1.xlsx")
# data1

# %%
data1['holiday'].unique()
# Out:
# array([False,  True])

# %%
data1['weekday'].unique()
# Out:
# array([6, 0, 1, 2, 3, 4, 5])

# %%
data1['weekday'].value_counts()
# Out:
# weekday
# 6    95
# 0    94
# 1    93
# 5    85
# 3    84
# 2    80
# 4    79
# Name: count, dtype: int64

# %%
data1['weathersit'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
data1['weathersit'].value_counts()
# Out:
# weathersit
# 1    368
# 2    194
# 3     47
# 4      1
# Name: count, dtype: int64

# %%
data1['holiday'].unique()
# Out:
# array([False,  True])

# %%
holiday_data1 = data1[data1['holiday'] == True]
holiday_data1=holiday_data1[['weathersit', 'hr', 'temp', 'dteday','holiday']]
holiday_data1
# Out:
#      weathersit  hr  temp    dteday  holiday
# 372           2   0  0.20  20110117     True
# 373           2   1  0.20  20110117     True
# 374           2   2  0.18  20110117     True
# 375           2   3  0.18  20110117     True
# 376           2   4  0.18  20110117     True
# 377           2   5  0.18  20110117     True
# 378           2   6  0.18  20110117     True
# 379           2   7  0.16  20110117     True
# 380           2   8  0.16  20110117     True
# 381           2   9  0.16  20110117     True
# 382           2  10  0.16  20110117     True
# 383           2  11  0.16  20110117     True
# 384           2  12  0.18  20110117     True
# 385           2  13  0.18  20110117     True
# 386           2  14  0.18  20110117     True
# 387           2  15  0.20  20110117     True
# 388           2  16  0.20  20110117     True
# 389           1  17  0.20  20110117     True
# 390           2  18  0.18  20110117     True
# 391           3  19  0.18  20110117     True
# ...

# %%
holiday_data1['weathersit'].unique()
# Out:
# array([2, 1, 3])

# %%
holiday_data1['weathersit'].value_counts()
# Out:
# weathersit
# 2    18
# 3     5
# 1     1
# Name: count, dtype: int64

# %% [markdown]
# ### on holiday user like to go on ride and praticular when weathersit is 2 with maximum ride 18 hrs ride

# %%
holiday_data1.to_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/holiday_data1.xlsx")

# %%
hd1=pd.read_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/holiday_data1.xlsx")
hd1
# Out:
#     Unnamed: 0  weathersit  hr  temp    dteday  holiday
# 0          372           2   0  0.20  20110117     True
# 1          373           2   1  0.20  20110117     True
# 2          374           2   2  0.18  20110117     True
# 3          375           2   3  0.18  20110117     True
# 4          376           2   4  0.18  20110117     True
# 5          377           2   5  0.18  20110117     True
# 6          378           2   6  0.18  20110117     True
# 7          379           2   7  0.16  20110117     True
# 8          380           2   8  0.16  20110117     True
# 9          381           2   9  0.16  20110117     True
# 10         382           2  10  0.16  20110117     True
# 11         383           2  11  0.16  20110117     True
# 12         384           2  12  0.18  20110117     True
# 13         385           2  13  0.18  20110117     True
# 14         386           2  14  0.18  20110117     True
# 15         387           2  15  0.20  20110117     True
# ...

# %%
hd1.drop(['Unnamed: 0'], axis=1, inplace=True)
hd1
# Out:
#     weathersit  hr  temp    dteday  holiday
# 0            2   0  0.20  20110117     True
# 1            2   1  0.20  20110117     True
# 2            2   2  0.18  20110117     True
# 3            2   3  0.18  20110117     True
# 4            2   4  0.18  20110117     True
# 5            2   5  0.18  20110117     True
# 6            2   6  0.18  20110117     True
# 7            2   7  0.16  20110117     True
# 8            2   8  0.16  20110117     True
# 9            2   9  0.16  20110117     True
# 10           2  10  0.16  20110117     True
# 11           2  11  0.16  20110117     True
# 12           2  12  0.18  20110117     True
# 13           2  13  0.18  20110117     True
# 14           2  14  0.18  20110117     True
# 15           2  15  0.20  20110117     True
# 16           2  16  0.20  20110117     True
# 17           1  17  0.20  20110117     True
# 18           2  18  0.18  20110117     True
# 19           3  19  0.18  20110117     True
# ...

# %%
data2=pd.read_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/dataset_2.xlsx")
data2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
data2.drop(['Unnamed: 0'], axis=1, inplace=True)
data2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
data2.shape
# Out:
# (610, 7)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   atemp       599 non-null    float64
#  2   hum         610 non-null    float64
#  3   windspeed   610 non-null    float64
#  4   casual      610 non-null    int64
#  5   registered  610 non-null    int64
#  6   cnt         610 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 33.5 KB

# %%
data2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# ### In dataset2 we find **atemp** have 11 null rows
#
#
# 1.   Try to find percetage if null data of atemp column. if it is not more thab 40% to 50% then we can replace
# 2.   to replace we find mean and medain which on work better that we replace

# %%
data2.isnull().sum()/data2.shape[0]*100
# Out:
# instant       0.000000
# atemp         1.803279
# hum           0.000000
# windspeed     0.000000
# casual        0.000000
# registered    0.000000
# cnt           0.000000
# dtype: float64

# %%
mean=data2['atemp'].mean()
mean
# Out:
# 0.19993489148580967

# %%
md=data2['atemp'].median()
md
# Out:
# 0.197

# %%
data2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
data2['atemp'].fillna(value=md, inplace=True)
data2.isnull().sum()
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ## Round the decimal point to uderstand the data easily and better way

# %%
updated_data2=data2.round({"atemp":2, "windspeed":2 })
updated_data2
# Out:
#      instant  atemp   hum  windspeed  casual  registered  cnt
# 0          1   0.29  0.81        0.0       3          13   16
# 1          2   0.27  0.80        0.0       8          32   40
# 2          3   0.27  0.80        0.0       5          27   32
# 3          4   0.29  0.75        0.0       3          10   13
# 4          5   0.29  0.75        0.0       0           1    1
# ..       ...    ...   ...        ...     ...         ...  ...
# 605      606   0.21  0.93        0.1       0          30   30
# 606      607   0.21  0.93        0.1       1          28   29
# 607      608   0.21  0.93        0.1       0          31   31
# 608      609   0.27  0.80        0.0       2          36   38
# 609      610   0.26  0.86        0.0       1          40   41
#
# [610 rows x 7 columns]

# %% [markdown]
# updated_data2.to_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/dataset_2.xlsx")
#
# updated_data2

# %% [markdown]
# clean_data2=pd.read_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/dataset_2.xlsx")
# clean_data2

# %% [markdown]
# clean_data2.drop(['Unnamed: 0'], axis=1, inplace=True)
# clean_data2

# %%
combine_data=pd.merge(data1,updated_data2, on='instant', how='inner')
combine_data
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1  20110101       1     1   0    False        6           1  0.24
# 1          2  20110101       1     1   1    False        6           1  0.22
# 2          3  20110101       1     1   2    False        6           1  0.22
# 3          4  20110101       1     1   3    False        6           1  0.24
# 4          5  20110101       1     1   4    False        6           1  0.24
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 605      606  20110128       1     1  11    False        5           3  0.18
# 606      607  20110128       1     1  12    False        5           3  0.18
# 607      608  20110128       1     1  13    False        5           3  0.18
# 608      609  20110128       1     1  14    False        5           3  0.22
# 609      610  20110128       1     1  15    False        5           2  0.20
#
# ...

# %%
combine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    int64
#  2   season      610 non-null    int64
#  3   mnth        610 non-null    int64
#  4   hr          610 non-null    int64
#  5   holiday     610 non-null    bool
#  6   weekday     610 non-null    int64
#  7   weathersit  610 non-null    int64
#  8   temp        610 non-null    float64
#  9   atemp       610 non-null    float64
#  10  hum         610 non-null    float64
#  11  windspeed   610 non-null    float64
#  12  casual      610 non-null    int64
#  13  registered  610 non-null    int64
#  14  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(10)
# memory usage: 67.4 KB

# %%
combine_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
data3=pd.read_excel("/content/drive/MyDrive/DatacquisitiondataWrangling/dataset_3.xlsx")
data3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
data3.drop(['yr'], axis=1, inplace=True)
data3
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620 2011-01-29       1     1   1    False        6           1  0.22
# 1        621 2011-01-29       1     1   2    False        6           1  0.22
# 2        622 2011-01-29       1     1   3    False        6           1  0.20
# 3        623 2011-01-29       1     1   4    False        6           1  0.16
# 4        624 2011-01-29       1     1   6    False        6           1  0.16
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 385      615 2011-01-28       1     1  20    False        5           2  0.24
# 386      616 2011-01-28       1     1  21    False        5           2  0.22
# 387      617 2011-01-28       1     1  22    False        5           1  0.24
# 388      618 2011-01-28       1     1  23    False        5           1  0.24
# 389      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %%
data3['dteday'] = pd.to_datetime(data3['dteday']).dt.strftime('%Y%m%d').astype(int)
data3
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620  20110129       1     1   1    False        6           1  0.22
# 1        621  20110129       1     1   2    False        6           1  0.22
# 2        622  20110129       1     1   3    False        6           1  0.20
# 3        623  20110129       1     1   4    False        6           1  0.16
# 4        624  20110129       1     1   6    False        6           1  0.16
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 385      615  20110128       1     1  20    False        5           2  0.24
# 386      616  20110128       1     1  21    False        5           2  0.22
# 387      617  20110128       1     1  22    False        5           1  0.24
# 388      618  20110128       1     1  23    False        5           1  0.24
# 389      619  20110129       1     1   0    False        6           1  0.22
#
# ...

# %%
data3.shape
# Out:
# (390, 15)

# %%
update_data3=data3.round({"atemp":2, "windspeed":2 })
update_data3
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620  20110129       1     1   1    False        6           1  0.22
# 1        621  20110129       1     1   2    False        6           1  0.22
# 2        622  20110129       1     1   3    False        6           1  0.20
# 3        623  20110129       1     1   4    False        6           1  0.16
# 4        624  20110129       1     1   6    False        6           1  0.16
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 385      615  20110128       1     1  20    False        5           2  0.24
# 386      616  20110128       1     1  21    False        5           2  0.22
# 387      617  20110128       1     1  22    False        5           1  0.24
# 388      618  20110128       1     1  23    False        5           1  0.24
# 389      619  20110129       1     1   0    False        6           1  0.22
#
# ...

# %%
update_data3['windspeed'].unique()
# Out:
# array([0.19, 0.16, 0.13, 0.1 , 0.09, 0.25, 0.  , 0.28, 0.22, 0.33, 0.3 ,
#        0.39, 0.52, 0.55, 0.49, 0.45, 0.36, 0.42, 0.46, 0.58])

# %%
update_data3['atemp'].unique()
# Out:
# array([0.23, 0.21, 0.18, 0.2 , 0.24, 0.29, 0.27, 0.32, 0.3 , 0.33, 0.26,
#        0.17, 0.14, 0.15, 0.39, 0.12, 0.36, 0.35, 0.11, 0.08, 0.41, 0.42])

# %%
update_data3.shape
# Out:
# (390, 15)

# %%
update_data3
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620  20110129       1     1   1    False        6           1  0.22
# 1        621  20110129       1     1   2    False        6           1  0.22
# 2        622  20110129       1     1   3    False        6           1  0.20
# 3        623  20110129       1     1   4    False        6           1  0.16
# 4        624  20110129       1     1   6    False        6           1  0.16
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 385      615  20110128       1     1  20    False        5           2  0.24
# 386      616  20110128       1     1  21    False        5           2  0.22
# 387      617  20110128       1     1  22    False        5           1  0.24
# 388      618  20110128       1     1  23    False        5           1  0.24
# 389      619  20110129       1     1   0    False        6           1  0.22
#
# ...

# %%
concat_data = pd.concat([combine_data, update_data3], axis=0)
concat_data
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1  20110101       1     1   0    False        6           1  0.24
# 1          2  20110101       1     1   1    False        6           1  0.22
# 2          3  20110101       1     1   2    False        6           1  0.22
# 3          4  20110101       1     1   3    False        6           1  0.24
# 4          5  20110101       1     1   4    False        6           1  0.24
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 385      615  20110128       1     1  20    False        5           2  0.24
# 386      616  20110128       1     1  21    False        5           2  0.22
# 387      617  20110128       1     1  22    False        5           1  0.24
# 388      618  20110128       1     1  23    False        5           1  0.24
# 389      619  20110129       1     1   0    False        6           1  0.22
#
# ...

# %%
concat_data.shape
# Out:
# (1000, 15)

# %%
concat_data['atemp'].unique()
# Out:
# array([0.29, 0.27, 0.26, 0.2 , 0.35, 0.39, 0.33, 0.42, 0.45, 0.44, 0.41,
#        0.23, 0.21, 0.14, 0.11, 0.12, 0.17, 0.18, 0.24, 0.15, 0.32, 0.06,
#        0.08, 0.09, 0.3 , 0.03, 0.05, 0.  , 0.02, 0.36])

# %%
concat_data['windspeed'].unique()
# Out:
# array([0.  , 0.09, 0.25, 0.28, 0.3 , 0.19, 0.22, 0.13, 0.16, 0.33, 0.45,
#        0.36, 0.42, 0.39, 0.1 , 0.49, 0.55, 0.46, 0.52, 0.58])

# %%
concat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 389
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   int64
#  2   season      1000 non-null   int64
#  3   mnth        1000 non-null   int64
#  4   hr          1000 non-null   int64
#  5   holiday     1000 non-null   bool
#  6   weekday     1000 non-null   int64
#  7   weathersit  1000 non-null   int64
#  8   temp        1000 non-null   float64
#  9   atemp       1000 non-null   float64
#  10  hum         1000 non-null   float64
#  11  windspeed   1000 non-null   float64
#  12  casual      1000 non-null   int64
#  13  registered  1000 non-null   int64
#  14  cnt         1000 non-null   int64
# dtypes: bool(1), float64(4), int64(10)
# memory usage: 118.2 KB

# %%
concat_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
concat_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# Length: 1000, dtype: bool

# %%
concat_data.duplicated().sum()
# Out:
# 0

# %%
hoildayride = concat_data[concat_data['holiday'] == True]
hoildayride=hoildayride[['weathersit', 'hr', 'temp', 'dteday','holiday','casual','registered']]
hoildayride
# Out:
#      weathersit  hr  temp    dteday  holiday  casual  registered
# 372           2   0  0.20  20110117     True       1          16
# 373           2   1  0.20  20110117     True       1          15
# 374           2   2  0.18  20110117     True       0           8
# 375           2   3  0.18  20110117     True       0           2
# 376           2   4  0.18  20110117     True       1           2
# 377           2   5  0.18  20110117     True       0           1
# 378           2   6  0.18  20110117     True       0           5
# 379           2   7  0.16  20110117     True       4           9
# 380           2   8  0.16  20110117     True       3          30
# 381           2   9  0.16  20110117     True       8          39
# 382           2  10  0.16  20110117     True       7          50
# 383           2  11  0.16  20110117     True       9          55
# 384           2  12  0.18  20110117     True      10          70
# ...

# %%
hoildayride.shape
# Out:
# (24, 7)

# %%
concat_data
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1  20110101       1     1   0    False        6           1  0.24
# 1          2  20110101       1     1   1    False        6           1  0.22
# 2          3  20110101       1     1   2    False        6           1  0.22
# 3          4  20110101       1     1   3    False        6           1  0.24
# 4          5  20110101       1     1   4    False        6           1  0.24
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 385      615  20110128       1     1  20    False        5           2  0.24
# 386      616  20110128       1     1  21    False        5           2  0.22
# 387      617  20110128       1     1  22    False        5           1  0.24
# 388      618  20110128       1     1  23    False        5           1  0.24
# 389      619  20110129       1     1   0    False        6           1  0.22
#
# ...

# %%
concat_data['mnth'].unique()
# Out:
# array([1, 2])

# %%
sns.boxplot(concat_data["mnth"], color='brown')
plt.title('Finding outliers for the column mnth')
plt.show()

# %%
sns.boxplot(y=concat_data["hr"], color='grey')
plt.title('Finding outliers for the column Hours')
plt.show()

# %%
sns.boxplot(concat_data["weekday"], color='yellow')
plt.title('Finding outliers for the column Weekdays')
plt.show()

# %%
sns.boxplot(y=concat_data["weathersit"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
concat_data.shape
# Out:
# (1000, 15)

# %%
Q1 = concat_data['weathersit'].quantile(0.25)
Q3 = concat_data['weathersit'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = concat_data['weathersit'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = concat_data['weathersit'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = concat_data[~(lower_array | upper_array)]

print("Old Shape: ", concat_data.shape)
print("New Shape: ", data_nooutliers1.shape)
# Out:
# Q1:  1.0
# Q3:  2.0
# IQR: 1.0
# Lower Bound: -0.5
# 0
# Upper Bound: 3.5
# 1
# Old Shape:  (1000, 15)
# New Shape:  (999, 15)

# %%
sns.boxplot(y=data_nooutliers1["temp"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
print("Old Shape: ", data_nooutliers1.shape)

Q1 = data_nooutliers1['temp'].quantile(0.25)
Q3 = data_nooutliers1['temp'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = data_nooutliers1['temp'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = data_nooutliers1['temp'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = data_nooutliers1[~(lower_array | upper_array)]


print("New Shape: ", data_nooutliers1.shape)
# Out:
# Old Shape:  (999, 15)
# Q1:  0.16
# Q3:  0.24
# IQR: 0.07999999999999999
# Lower Bound: 0.04000000000000002
# 24
# Upper Bound: 0.36
# 57
# New Shape:  (918, 15)

# %%
sns.boxplot(y=data_nooutliers1["atemp"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
print("Old Shape: ", data_nooutliers1.shape)

Q1 = data_nooutliers1['atemp'].quantile(0.25)
Q3 = data_nooutliers1['atemp'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = data_nooutliers1['atemp'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = data_nooutliers1['atemp'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = data_nooutliers1[~(lower_array | upper_array)]


print("New Shape: ", data_nooutliers1.shape)
# Out:
# Old Shape:  (918, 15)
# Q1:  0.17
# Q3:  0.24
# IQR: 0.06999999999999998
# Lower Bound: 0.06500000000000004
# 7
# Upper Bound: 0.345
# 11
# New Shape:  (900, 15)

# %%
sns.boxplot(y=data_nooutliers1["hum"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
sns.boxplot(y=data_nooutliers1["windspeed"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
print("Old Shape: ", data_nooutliers1.shape)

Q1 = data_nooutliers1['windspeed'].quantile(0.25)
Q3 = data_nooutliers1['windspeed'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = data_nooutliers1['windspeed'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = data_nooutliers1['windspeed'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = data_nooutliers1[~(lower_array | upper_array)]


print("New Shape: ", data_nooutliers1.shape)
# Out:
# Old Shape:  (900, 15)
# Q1:  0.1
# Q3:  0.28
# IQR: 0.18000000000000002
# Lower Bound: -0.17
# 0
# Upper Bound: 0.55
# 8
# New Shape:  (892, 15)

# %%
concat_data
# Out:
#      instant    dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1  20110101       1     1   0    False        6           1  0.24
# 1          2  20110101       1     1   1    False        6           1  0.22
# 2          3  20110101       1     1   2    False        6           1  0.22
# 3          4  20110101       1     1   3    False        6           1  0.24
# 4          5  20110101       1     1   4    False        6           1  0.24
# ..       ...       ...     ...   ...  ..      ...      ...         ...   ...
# 385      615  20110128       1     1  20    False        5           2  0.24
# 386      616  20110128       1     1  21    False        5           2  0.22
# 387      617  20110128       1     1  22    False        5           1  0.24
# 388      618  20110128       1     1  23    False        5           1  0.24
# 389      619  20110129       1     1   0    False        6           1  0.22
#
# ...

# %%
sns.boxplot(y=data_nooutliers1["casual"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
print("Old Shape: ", data_nooutliers1.shape)

Q1 = data_nooutliers1['casual'].quantile(0.25)
Q3 = data_nooutliers1['casual'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = data_nooutliers1['casual'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = data_nooutliers1['casual'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = data_nooutliers1[~(lower_array | upper_array)]


print("New Shape: ", data_nooutliers1.shape)
# Out:
# Old Shape:  (892, 15)
# Q1:  0.0
# Q3:  6.0
# IQR: 6.0
# Lower Bound: -9.0
# 0
# Upper Bound: 15.0
# 49
# New Shape:  (843, 15)

# %%
sns.boxplot(y=data_nooutliers1["registered"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
print("Old Shape: ", data_nooutliers1.shape)

Q1 = data_nooutliers1['registered'].quantile(0.25)
Q3 = data_nooutliers1['registered'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = data_nooutliers1['registered'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = data_nooutliers1['registered'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = data_nooutliers1[~(lower_array | upper_array)]


print("New Shape: ", data_nooutliers1.shape)
# Out:
# Old Shape:  (843, 15)
# Q1:  13.0
# Q3:  70.0
# IQR: 57.0
# Lower Bound: -72.5
# 0
# Upper Bound: 155.5
# 46
# New Shape:  (797, 15)

# %%
sns.boxplot(y=data_nooutliers1["cnt"], color='blue')
plt.title('Finding outliers for the column weathersit')
plt.show()

# %%
print("Old Shape: ", data_nooutliers1.shape)

Q1 = data_nooutliers1['cnt'].quantile(0.25)
Q3 = data_nooutliers1['cnt'].quantile(0.75)
IQR = Q3 - Q1
print("Q1: ", Q1, "\nQ3: ",Q3, "\nIQR:",IQR)


lower = Q1 - 1.5 * IQR
lower_array = data_nooutliers1['cnt'] <= lower
print("Lower Bound:", lower)
print(lower_array.sum())

upper = Q3 + 1.5 * IQR
upper_array = data_nooutliers1['cnt'] >= upper
print("Upper Bound:", upper)
print(upper_array.sum())

data_nooutliers1 = data_nooutliers1[~(lower_array | upper_array)]


print("New Shape: ", data_nooutliers1.shape)
# Out:
# Old Shape:  (797, 15)
# Q1:  13.0
# Q3:  69.0
# IQR: 56.0
# Lower Bound: -71.0
# 0
# Upper Bound: 153.0
# 12
# New Shape:  (785, 15)
